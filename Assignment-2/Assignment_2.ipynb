# %% [markdown]
# # WITH SEABORN

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# INSTRUCTIONS
# 1. Box and Swarm Plots in kill data
# 1. Most dangerous cities
# 1. Most dangerous states
# 1. Having mental ilness or not for killed people
# 1. Threat types
# 1. Flee types
# <br>

# %%
kill = pd.read_csv('PoliceKillingsUS.csv', encoding="windows-1252")

# %%
df = kill.copy()
df.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
# Out:
#    id                name      date  ... threat_level         flee  body_camera
# 0   3          Tim Elliot  02/01/15  ...       attack  Not fleeing        False
# 1   4    Lewis Lee Lembke  02/01/15  ...       attack  Not fleeing        False
# 2   5  John Paul Quintero  03/01/15  ...        other  Not fleeing        False
# 3   8     Matthew Hoffman  04/01/15  ...       attack  Not fleeing        False
# 4   9   Michael Rodriguez  04/01/15  ...       attack  Not fleeing        False
#
# [5 rows x 14 columns]

# %%
df.shape
# Out:
# (2535, 14)

# %%
# Out:
# (2535, 14)

# %%
df.duplicated().value_counts()
# Out:
# False    2535
# dtype: int64

# %%
df.isnull().sum()
# Out:
# id                           0
# name                         0
# date                         0
# manner_of_death              0
# armed                        9
# age                         77
# gender                       0
# race                       195
# city                         0
# state                        0
# signs_of_mental_illness      0
# threat_level                 0
# flee                        65
# body_camera                  0
# dtype: int64

# %%
df.value_counts()
# Out:
# id    name                      date      manner_of_death   armed         age   gender  race  city          state  signs_of_mental_illness  threat_level  flee         body_camera
# 3     Tim Elliot                02/01/15  shot              gun           53.0  M       A     Shelton       WA     True                     attack        Not fleeing  False          1
# 1783  Dominic Rollice           12/08/16  shot and Tasered  hammer        49.0  M       W     Tahlequah     OK     True                     other         Not fleeing  True           1
# 1776  Jesse James Romero        09/08/16  shot              gun           14.0  M       H     Los Angeles   CA     False                    attack        Foot         True           1
# 1777  Jeffrey Allen Morris      09/08/16  shot              undetermined  44.0  M       W     Piedmont      SC     False                    other         Not fleeing  False          1
# ...

# %% [markdown]
# ## 1a: Box plot of age in both genders separeted by manner of death.

# %%
# Out:
#    id                name      date  ... threat_level         flee  body_camera
# 0   3          Tim Elliot  02/01/15  ...       attack  Not fleeing        False
# 1   4    Lewis Lee Lembke  02/01/15  ...       attack  Not fleeing        False
# 2   5  John Paul Quintero  03/01/15  ...        other  Not fleeing        False
# 3   8     Matthew Hoffman  04/01/15  ...       attack  Not fleeing        False
# 4   9   Michael Rodriguez  04/01/15  ...       attack  Not fleeing        False
#
# [5 rows x 14 columns]

# %%
df.sample(5)
# Out:
#         id                       name  ...         flee body_camera
# 1407  1593  Christopher Michael Moran  ...          Car       False
# 1734  1946              Eddie Collins  ...  Not fleeing       False
# 128    167      Jason Moncrief Carter  ...  Not fleeing       False
# 1421  1611           Clayton Millsaps  ...  Not fleeing       False
# 1406  1598         Larry Dustin Stepp  ...  Not fleeing        True
#
# [5 rows x 14 columns]

# %%
df["manner_of_death"].value_counts().index
# Out:
# Index(['shot', 'shot and Tasered'], dtype='object')

# %%
# Out:
# array(['shot', 'shot and Tasered'], dtype=object)

# %% [markdown]
# **INSTRUCTION: Demonstrate the Qurtiles of age in both genders separeted by manner of death.**

# %%
# with seaborn

# %%
sns.boxplot(x="gender", y= "age", data= df, hue="manner_of_death");

# %% [markdown]
# ## 1b: Swarm Plot

# %% [markdown]
# **INSTRUCTION: Demonstrate the age in both genders separeted by manner of death by a swarm plot.**

# %%
# with seaborn

# %%
plt.figure(figsize= (10, 8))
sns.swarmplot(x="gender", y= "age", data= df, hue="manner_of_death");

# %% [markdown]
# ## 2: Plot 12 most dangerous cities

# %%
df.sample()
# Out:
#         id              name      date  ... threat_level  flee  body_camera
# 1215  1393  Abraham Martinez  20/03/16  ...       attack  Foot        False
#
# [1 rows x 14 columns]

# %%
city_freq = (df["city"].value_counts().sort_values(ascending= False).head(12))
city_freq
# Out:
# Los Angeles     39
# Phoenix         31
# Houston         27
# Chicago         25
# Las Vegas       21
# San Antonio     20
# Columbus        19
# Austin          18
# Miami           18
# St. Louis       15
# Albuquerque     14
# Indianapolis    14
# Name: city, dtype: int64

# %%
city_freq = 
city_freq
# Out:
# Los Angeles      39
# Phoenix          31
# Houston          27
# Chicago          25
# Las Vegas        21
# San Antonio      20
# Columbus         19
# Austin           18
# Miami            18
# St. Louis        15
# Oklahoma City    14
# Tucson           14
# Name: city, dtype: int64

# %%
city_freq.index
# Out:
# Index(['Los Angeles', 'Phoenix', 'Houston', 'Chicago', 'Las Vegas',
#        'San Antonio', 'Columbus', 'Austin', 'Miami', 'St. Louis',
#        'Albuquerque', 'Indianapolis'],
#       dtype='object')

# %%
city_freq.values
# Out:
# array([39, 31, 27, 25, 21, 20, 19, 18, 18, 15, 14, 14])

# %%
# with seaborn barplot
fig, ax =plt.subplots(figsize=(8,5))
ax = 
ax.
ax.

# %%
# with seaborn barplot
fig, ax = plt.subplots(figsize=(8, 5))
sns.barplot(x=city_freq.index, y=city_freq.values ).set_title('Most Dangerous Cities',
 fontdict= { 'fontsize': 15,'color':'blue'})
plt.xticks(rotation=45)
for p in ax.patches: 
    ax.annotate(p.get_height(), (p.get_x()+0.2 , p.get_height()+0.3 ) );

# %%
# with seaborn countplot
fig, ax =plt.subplots(figsize=(8,5))
sns.
ax.
ax.

# %%
fig, ax = plt.subplots(figsize=(8, 5))

a = df.city.value_counts().iloc[:12].index
sns.countplot(x='city', data=df, order= a).set_title("Most Dangerous Cities",
fontdict= {'fontsize': 15,'color':'blue'})
plt.xticks(rotation=45)
for p in ax.patches: 
    ax.annotate(p.get_height(), (p.get_x()+0.2, p.get_height()+0.3 ));

# %% [markdown]
# ## 3: Plot 20 most dangerous states

# %%
df.sample()
# Out:
#       id         name      date  ... threat_level flee  body_camera
# 193  209  Aaron Siler  14/03/15  ...       attack  Car        False
#
# [1 rows x 14 columns]

# %%
state_freq = df["state"].value_counts().sort_values(ascending= False)[:20]
state_freq
# Out:
# CA    424
# TX    225
# FL    154
# AZ    118
# OH     79
# OK     78
# CO     74
# GA     70
# NC     69
# MO     64
# IL     62
# WA     62
# TN     59
# LA     57
# PA     51
# NM     51
# AL     50
# VA     47
# NY     45
# SC     44
# Name: state, dtype: int64

# %%
state_freq = 
state_freq
# Out:
# CA    424
# TX    225
# FL    154
# AZ    118
# OH     79
# OK     78
# CO     74
# GA     70
# NC     69
# MO     64
# IL     62
# WA     62
# TN     59
# LA     57
# PA     51
# NM     51
# AL     50
# VA     47
# NY     45
# SC     44
# Name: state, dtype: int64

# %%
# with seaborn barplot
fig, ax =plt.subplots(figsize=(8,5))
ax = 
ax.
ax.

# %%
fig, ax = plt.subplots(figsize=(8, 5))
a = state_freq.index
b = state_freq.values
sns.barplot(x=a , y= b).set_title("Most Dangerous States",
                                  fontdict= {'fontsize': 18,'color':'blue'})
plt.xticks(rotation=45)
for p in ax.patches: 
    ax.annotate(p.get_height(), (p.get_x()+ 0.1 , p.get_height()+ 5));

# %%
# with seaborn countplot
fig, ax =plt.subplots(figsize=(8,5))
sns.
ax.
ax.

# %%
fig, ax = plt.subplots(figsize=(8, 5))
h = kill.state.value_counts().iloc[:20].index
sns.countplot(x="state", data=df, order= h).set_title("Most Dangerous States",
                                                      fontdict= {'fontsize': 18,'color':'blue'})
plt.xticks(rotation=45)
for p in ax.patches: 
    ax.annotate(p.get_height(), (p.get_x()+0.1 , p.get_height()+5 ) );

# %% [markdown]
# ## 4: Plot Having mental ilness or not for killed people

# %%
df.columns
# Out:
# Index(['id', 'name', 'date', 'manner_of_death', 'armed', 'age', 'gender',
#        'race', 'city', 'state', 'signs_of_mental_illness', 'threat_level',
#        'flee', 'body_camera'],
#       dtype='object')

# %%
illness = df["signs_of_mental_illness"].value_counts()
illness
# Out:
# False    1902
# True      633
# Name: signs_of_mental_illness, dtype: int64

# %%
illness = 
illness
# Out:
# False    1902
# True      633
# Name: signs_of_mental_illness, dtype: int64

# %%
# with seaborn

# %%
sns.countplot(x= illness);

# %% [markdown]
# ## 5: Plot number of Threat Types

# %%
threads_freq = df["threat_level"].value_counts()
threads_freq
# Out:
# attack          1611
# other            766
# undetermined     158
# Name: threat_level, dtype: int64

# %%
threads_freq = 
threads_freq
# Out:
# attack          1611
# other            766
# undetermined     158
# Name: threat_level, dtype: int64

# %%
# with seaborn

# %%
fig, ax = plt.subplots(figsize=(6,4))
sns.countplot(x= "threat_level", data= df)
for p in ax.patches: 
    ax.annotate(p.get_height(), (p.get_x()+ 0.3 , p.get_height()+ 15));

# %% [markdown]
# ## 6: Plot number of Flee Types

# %%
flee_freq = df["flee"].value_counts()
flee_freq
# Out:
# Not fleeing    1695
# Car             385
# Foot            294
# Other            96
# Name: flee, dtype: int64

# %%
flee_freq = 
flee_freq
# Out:
# Not fleeing    1695
# Car             385
# Foot            294
# Other            96
# Name: flee, dtype: int64

# %%
# with seaborn

# %%
fig, ax = plt.subplots(figsize=(6,4))
sns.countplot(x="flee", data= df)
for p in ax.patches: 
    ax.annotate(p.get_height(), (p.get_x()+0.2 , p.get_height()+ 15));
