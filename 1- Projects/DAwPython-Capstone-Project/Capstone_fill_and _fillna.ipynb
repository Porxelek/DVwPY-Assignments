# %%
import pandas as pd
import re
import numpy as np
import seaborn as sns
sns.set_style("whitegrid")

import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.options.display.max_rows=100
pd.options.display.max_columns=100

# %%
data = pd.read_csv("scout_car_clean.csv")
df = data.copy()

# %%
df.columns
# Out:
# Index(['Safety_Security', 'Extras', 'Entertainment_Media',
#        'Comfort_Convenience', 'Emission_Class', 'CO2_Emission', 'Consumption',
#        'Fuel', 'Drive_chain', 'Cylinders', 'Displacement', 'Gearing_Type',
#        'Seats', 'Doors', 'Upholstery', 'Body_Color_Original', 'Paint_Type',
#        'Body_Color', 'First_Registration', 'Non_smoking_Vehicle',
#        'Full_Service', 'Warranty', 'Type', 'hp', 'prev_owner', 'km', 'vat',
#        'price', 'body_type', 'make_model', 'url', 'description',
#        'Emission_Label', 'Gears', 'Country_version',
#        'Last_Timing_Belt_Service_Date'],
#       dtype='object')

# %%
df.sample(3).T
# Out:
#                                                                             3565  \
# Safety_Security                ['ABS', 'Alarm system', 'Central door lock wit...
# Extras                                                          ['Alloy wheels']
# Entertainment_Media                                   ['Bluetooth', 'CD player']
# Comfort_Convenience            ['Air conditioning', 'Armrest', 'Electrical si...
# Emission_Class                                                               NaN
# CO2_Emission                                                  98 g CO2/km (comb)
# Consumption                                                                3.700
# Fuel                                                 Diesel (Particulate Filter)
# Drive_chain                                                                  NaN
# Cylinders                                                                  4.000
# Displacement                                                             1598 cc
# Gearing_Type                                                              Manual
# Seats                                                                      5.000
# Doors                                                                      4.000
# Upholstery                                                                   NaN
# Body_Color_Original                                                          NaN
# Paint_Type                                                                   NaN
# Body_Color                                                                 Black
# First_Registration                                                      2016.000
# Non_smoking_Vehicle                                                          NaN
# Full_Service                                                                 NaN
# Warranty                                                                     NaN
# Type                                                                        Used
# hp                                                                            81
# prev_owner                                                                   NaN
# km                                                                        116000
# vat                                                                          NaN
# price                                                                      15990
# body_type                                                                 Sedans
# make_model                                                               Audi A3
# url                            https://www.autoscout24.com//offers/audi-a3-1-...
# description                    ['\nsportbak, CO : 99, airco, start stop, navi...
# Emission_Label                                                               NaN
# Gears                                                                      6.000
# Country_version                                                              NaN
# Last_Timing_Belt_Service_Date                                                NaN
#
#                                                                             4371  \
# Safety_Security                ['ABS', 'Alarm system', 'Driver-side airbag', ...
# Extras                                                          ['Alloy wheels']
# Entertainment_Media                                                          NaN
# Comfort_Convenience            ['Air conditioning', 'Automatic climate contro...
# Emission_Class                                                               NaN
# CO2_Emission                                                                 NaN
# Consumption                                                                  NaN
# Fuel                                                                      Diesel
# Drive_chain                                                                  NaN
# Cylinders                                                                  4.000
# Displacement                                                             1598 cc
# Gearing_Type                                                              Manual
# Seats                                                                        NaN
# Doors                                                                        NaN
# Upholstery                                                                   NaN
# Body_Color_Original                                                        NEGRO
# Paint_Type                                                                   NaN
# Body_Color                                                                 Black
# First_Registration                                                      2017.000
# Non_smoking_Vehicle                                                          NaN
# Full_Service                                                                 NaN
# Warranty                                                                     NaN
# Type                                                                        Used
# hp                                                                            81
# prev_owner                                                                   NaN
# km                                                                         54740
# vat                                                                          NaN
# price                                                                      16900
# body_type                                                                 Sedans
# make_model                                                               Audi A3
# url                            https://www.autoscout24.com//offers/audi-a3-sp...
# description                    ['\nABS+EBV+EDS+ASR+ESP, Airbag conductor y ac...
# Emission_Label                                                               NaN
# Gears                                                                      6.000
# Country_version                                                              NaN
# Last_Timing_Belt_Service_Date                                                NaN
#
#                                                                             6554
# Safety_Security                ['ABS', 'Central door lock', 'Daytime running ...
# Extras                                                          ['Alloy wheels']
# Entertainment_Media            ['Bluetooth', 'Hands-free equipment', 'On-boar...
# Comfort_Convenience            ['Air conditioning', 'Electrical side mirrors'...
# Emission_Class                                                          4 (Green
# CO2_Emission                                                 128 g CO2/km (comb)
# Consumption                                                                5.400
# Fuel                                                                    Gasoline
# Drive_chain                                                                  NaN
# Cylinders                                                                    NaN
# Displacement                                                             1399 cc
# Gearing_Type                                                              Manual
# Seats                                                                      5.000
# Doors                                                                      4.000
# Upholstery                                                          Cloth, Black
# Body_Color_Original                                                          NaN
# Paint_Type                                                              Metallic
# Body_Color                                                                Silver
# First_Registration                                                      2017.000
# Non_smoking_Vehicle                                                       Euro 6
# Full_Service                                                 128 g CO2/km (comb)
# Warranty                                                                     NaN
# Type                                                                        Used
# hp                                                                            74
# prev_owner                                                                 1.000
# km                                                                          3898
# vat                                                                          NaN
# price                                                                      10990
# body_type                                                                 Sedans
# make_model                                                            Opel Astra
# url                            https://www.autoscout24.com//offers/opel-astra...
# description                    ['\n', 'Fahrzeugbeschreibung', ' Sichern Sie s...
# Emission_Label                                                             Green
# Gears                                                                        NaN
# Country_version                                                              NaN
# Last_Timing_Belt_Service_Date                                                NaN

# %%
df["Warranty"].isnull().value_counts()
# Out:
# True     13123
# False     2796
# Name: Warranty, dtype: int64

# %%
df["Warranty"] = df["Warranty"].apply(lambda x: x.str.split()).str[0]
df["Warranty"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6740/3234777343.py in <module>
# ----> 1 df["Warranty"] = df["Warranty"].apply(lambda x: x.str.split()).str[0]
#       2 df["Warranty"].value_counts()
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4428         dtype: float64
#    4429         """
# -> 4430         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4431
#    4432     def _reduce(
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\apply.py in apply(self)
#    1080             return self.apply_str()
#    1081
# -> 1082         return self.apply_standard()
#    1083
#    1084     def agg(self):
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\apply.py in apply_standard(self)
#    1135                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1136                 # "Callable[[Any], Any]"
# -> 1137                 mapped = lib.map_infer(
#    1138                     values,
#    1139                     f,  # type: ignore[arg-type]
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\AppData\Local\Temp/ipykernel_6740/3234777343.py in <lambda>(x)
# ----> 1 df["Warranty"] = df["Warranty"].apply(lambda x: x.str.split()).str[0]
#       2 df["Warranty"].value_counts()
#
# AttributeError: 'float' object has no attribute 'str'
